# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('weight-height.csv')  # Ganti dengan nama file CSV kamu
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
#visualisasi statistik dasar
desc = df.describe()

desc.plot(kind='bar', figsize=(10,5))
plt.title("Statistik Deskriptif")
plt.ylabel("Nilai")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
x = df[['Height']]  # Variabel independen (misal: luas rumah, usia, pendapatan)
y = df['Weight']   

plt.figure(figsize=(8, 6))
sns.scatterplot(x=x['Height'], y=y)
plt.title("Scatter Plot")
plt.xlabel("Height")
plt.ylabel("Weight")
plt.show()

# %%
model = LinearRegression()
model.fit(x, y)

# 7. Tampilkan hasil regresi
print("\nModel Regresi Linier:")
print("Intercept:", model.intercept_)
print("Koefisien:", model.coef_[0])
# Out:
# Model Regresi Linier:
# Intercept: -350.73719181213767
# Koefisien: 7.717287640785399

# %%
y_pred = model.predict(x)
r2 = r2_score(y, y_pred)
print("R-squared:", r2)

# 9. Visualisasi garis regresi
plt.scatter(x, y, color='pink', label='Data Asli')
plt.plot(x, y_pred, color='red', label='Garis Regresi')
plt.xlabel('Height')
plt.ylabel('Weight')
plt.title('Regresi Linier Sederhana: Tinggi vs Berat')
plt.legend()
plt.show()
# Out:
# R-squared: 0.8551742120609958
