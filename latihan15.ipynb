# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

bulan = ['januari','Februari','Maret','April','Mei','Juni','Juli','Agustus','September','Oktober','November','Desember']

#Pengeluaran antara 500.000 - 2.000.000

Minggu_1 = np.random.randint(500000,2000001,12)
Minggu_2 = np.random.randint(500000,2000001,12)
Minggu_3 = np.random.randint(500000,2000001,12)
Minggu_4 = np.random.randint(500000,2000001,12)

data = {
    'Bulan' : bulan,
    'Minggu_1' : Minggu_1,
    'Minggu_2' : Minggu_2,
    'Minggu_3' : Minggu_3,
    'Minggu_4' : Minggu_4
}

df = pd.DataFrame(data)
df['Total_Pengeluaran'] = df[['Minggu_1','Minggu_2','Minggu_3','Minggu_4']].sum(axis=1)
df
# Out:
#         Bulan  Minggu_1  Minggu_2  Minggu_3  Minggu_4  Total_Pengeluaran
# 0     januari    620752   1081318    824390    773970            3300430
# 1    Februari   1265686    723265   1881425    963599            4833975
# 2       Maret   1561961    875787    717982   1986498            5142228
# 3       April   1003346   1940810    742259   1603632            5290047
# 4         Mei    992457    585348   1767784   1838796            5184385
# 5        Juni    953604   1653107   1870408    931329            5408448
# 6        Juli   1242744    959792    754237   1094401            4051174
# 7     Agustus    770519    783925   1995541   1185921            4735906
# 8   September    602112   1220933   1568807    657516            4049368
# 9     Oktober    691642    685427   1873790    586193            3837052
# 10   November   1258919   1149480   1882915    964565            5255879
# 11   Desember   1081572   1036767    797920   1652444            4568703

# %%
###### Total Pengeluaran Per Bulan

plt.figure(figsize=(12,6)) #
plt.title('Total Pengeluaran Per Bulan')
plt.bar(df['Bulan'],df['Total_Pengeluaran'],color = 'purple')
plt.xticks(rotation=45)
plt.ylabel('Rupiah')
plt.grid(axis='y')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Scatter plot untuk analisa data pengeluaran per minggu per bulan
plt.figure(figsize=(12,6))
for minggu in ['Minggu_1','Minggu_2','Minggu_3','Minggu_4']:
    plt.plot(df['Bulan'],df[minggu],marker='o',label=minggu)

plt.title("Pengeluaran Per Minggu")
plt.xlabel('Bulan')
plt.ylabel('Pengeluaran 9(Rupiah)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
#Pie_Chart -> Prosentase
plt.figure(figsize=(6,6))
plt.pie(df['Total_Pengeluaran'],labels=df['Bulan'],startangle=90,autopct='%1.1f%%')
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
from sklearn.linear_model import LinearRegression

df['Bulan_Angka'] = np.arange(1,13)

x = df[['Bulan_Angka']]
y = df['Total_Pengeluaran']

model = LinearRegression()

model.fit(x,y)

prediksi = model.predict([[13]])[0]
print(f"Hasil Prediksi adalah :{prediksi:,.0f}")
# Out:
# Hasil Prediksi adalah :4,631,447
# C:\Users\daffa\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
